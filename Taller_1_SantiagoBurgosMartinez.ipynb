# %% [markdown]
# **Tarea 1 Santiago Burgos Martínez**
# **Inteligencia Artificial**

# %% [markdown]
# # **Punto 1 Distribuciones Discretas**

# %%
import numpy  #as np# si no lo tiene instalado por favor correr en su consola         $pip install numpy
import scipy #as sp# si no lo tiene instalado por favor correr en su consola         $pip install scipy
import matplotlib #si no lo tiene instalado por favor correr  en su consola   $pip install matplotlib
import matplotlib.pyplot as plt
#Para todas las simulaciones:
N=100000
m=3000
numpy.random.seed(seed=2**32 - 1)

# %%
# bernoulli con cierto p entre 0 y 1
p=0.3 #variable de probabilidad
from scipy.stats import bernoulli
mean, var, skew, kurt = bernoulli.stats(p, moments='mvsk') #mvsk=>mean,var,skew,kurt
r = bernoulli.rvs(p, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos bernoulli con p="+str(p))
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos bernoulli ordenados con p="+str(p))
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos bernoulli con p="+str(p))
plt.show()
print("EL tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r") 
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la bernoulli con p=",p,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la bernoulli con p=",p,"son u_est=" ,avg,"var_est=",varest)
# Out:
# EL tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la bernoulli con p= 0.3 son u= 0.3 var= 0.21
# Los valores estimados en nuestro experimento de la media y varianza para la bernoulli con p= 0.3 son u_est= 0.29788 var_est= 0.20914750560000003

# %%
# binomial con cierto p entre 0 y 1 y cierto n
n=10 # Parametro
p=0.5 #variable de probabilidad
from scipy.stats import binom
mean, var, skew, kurt = binom.stats(n, p, moments='mvsk') #mvsk=>mean,var,skew,kurt
r = binom.rvs(n, p, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos binomial con n="+str(n)+" y p="+str(p))
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos binomial ordenados con n="+str(n)+" y  p="+str(p))
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos binomial con n="+str(n)+" y p="+str(p))
plt.show()
print("EL tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la binomial con n=",n,"y p=",p,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la binomial con n=",n,"y p=",p,"son u_est=" ,avg,"var_est=",varest)
# Out:
# EL tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la binomial con n= 10 y p= 0.5 son u= 5.0 var= 2.5
# Los valores estimados en nuestro experimento de la media y varianza para la binomial con n= 10 y p= 0.5 son u_est= 4.99334 var_est= 2.5004556443999997

# %%
# Geométrica con cierto p entre 0 y 1
p=0.3 #variable de probabilidad
from scipy.stats import geom
mean, var, skew, kurt = geom.stats(p, moments='mvsk') #mvsk=>mean,var,skew,kurt
r = geom.rvs(p, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos Geométrica con p="+str(p))
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos Geométrica ordenados con p="+str(p))
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos Geométrica con p="+str(p))
plt.show()
print("EL tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la Geométrica con p=",p,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la Geométrica con p=",p,"son u_est=" ,avg,"var_est=",varest)
# Out:
# EL tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la Geométrica con p= 0.3 son u= 3.3333333333333335 var= 7.777777777777779
# Los valores estimados en nuestro experimento de la media y varianza para la Geométrica con p= 0.3 son u_est= 3.31584 var_est= 7.697925094400001

# %%
# Poisson con cierto Lamnda L
L = 5 #variable de probabilidad
from scipy.stats import poisson
mean, var, skew, kurt = poisson.stats(L, moments='mvsk') #mvsk=>mean,var,skew,kurt
r = poisson.rvs(L, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos Poisson con L="+str(L))
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos Poisson ordenados con L="+str(L))
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos Poisson con L="+str(L))
plt.show()
print("EL tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la Poisson con L=",L,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la Poisson con L=",L,"son u_est=" ,avg,"var_est=",varest)
# Out:
# EL tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la Poisson con L= 5 son u= 5.0 var= 5.0
# Los valores estimados en nuestro experimento de la media y varianza para la Poisson con L= 5 son u_est= 4.99507 var_est= 4.9872656951

# %%
#Binomial negativa con parametro p después de r fallos
rf = 5
p = 0.5 #variable de probabilidad
from scipy.stats import nbinom
mean, var, skew, kurt = nbinom.stats(rf, p, moments='mvsk') #mvsk=>mean,var,skew,kurt
r = nbinom.rvs(rf, p, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos Binomial negativa con r="+str(rf)+" y p="+str(p))
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos Binomial negativa ordenados con r="+str(rf)+" p="+str(p))
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos Binomial negativa con r="+str(rf)+" p="+str(p))
plt.show()
print("EL tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r")
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la Binomial negativa con r=",rf,"y p=",p,"son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para la Binomial negativa con r=",rf,"y p=",p,"son u_est=" ,avg,"var_est=",varest)
# Out:
# EL tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la Binomial negativa con r= 5 y p= 0.5 son u= 5.0 var= 10.0
# Los valores estimados en nuestro experimento de la media y varianza para la Binomial negativa con r= 5 y p= 0.5 son u_est= 4.99138 var_est= 10.002205695599999

# %% [markdown]
# # **Punto 2 Distribuciones Continuas**

# %%
#Para todas las simulaciones:
N=1000
m=300
numpy.random.seed(seed=1314926535)#Para fijar una semilla para los experimentos y que los numeros generados siempre sean los mismos en cada corrida completa de este fuente.

# %%
# Normal de media 5 y desviación estandar 0.5
u=5
std=0.5
from scipy.stats import norm
mean, var, skew, kurt = norm.stats(loc=u,scale=std, moments='mvsk',)
r = norm.rvs (loc=u,scale=std, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos normales con media="+str(u)+" y std="+str(std))
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos normales ordenados con u="+str(u))
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos normales con u="+str(u)+ " y std= "+str(std))
plt.show()
print("EL tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r") 
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la normal son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza son u_est=" ,avg,"var_est=",varest)
# Out:
# EL tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la normal son u= 5.0 var= 0.25
# Los valores estimados en nuestro experimento de la media y varianza son u_est= 5.006855136192264 var_est= 0.22973332265098073

# %%
# Uniforme entre 0 y 255
from scipy.stats import uniform
mean, var, skew, kurt = uniform.stats(loc=0,scale=1, moments='mvsk',)
r = uniform.rvs (loc=0,scale=1, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos Uniforme")
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos Uniforme ordenados")
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos Uniforme")
plt.show()
print("EL tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r") 
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la Uniforme son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para Uniforme son u_est=" ,avg,"var_est=",varest)
# Out:
# EL tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la Uniforme son u= 0.5 var= 0.08333333333333333
# Los valores estimados en nuestro experimento de la media y varianza para Uniforme son u_est= 0.4970880311906078 var_est= 0.08227389373338184

# %%
# Exponencial con Lamnda L
L=0.3
from scipy.stats import expon
mean, var, skew, kurt = expon.stats( loc=0, scale=1/L, moments='mvsk',)
r = expon.rvs (loc=0,scale=1/L, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos Exponencial con L="+str(L))
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos Exponencial ordenados con L="+str(L))
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos Exponencial con L="+str(L))
plt.show()
print("EL tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r") 
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la Exponencial son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para Exponencial son u_est=" ,avg,"var_est=",varest)
# Out:
# EL tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la Exponencial son u= 3.3333333333333335 var= 11.111111111111112
# Los valores estimados en nuestro experimento de la media y varianza para Exponencial son u_est= 3.447080282247033 var_est= 10.657963380124478

# %%
#Chi cuadrada con K grados de libertad
K=3.0
from scipy.stats import chi2
mean, var, skew, kurt = chi2.stats(K, loc=0, scale=1, moments='mvsk',)
r = chi2.rvs (K, loc=0, scale=1, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos Chi cuadrada con K="+str(K))
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos Chi cuadrada ordenados con K="+str(K))
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos Chi cuadrada con K="+str(K))
plt.show()
print("EL tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r") 
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la Chi cuadrada son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para Chi cuadrada son u_est=" ,avg,"var_est=",varest)
# Out:
# EL tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la Chi cuadrada son u= 3.0 var= 6.0
# Los valores estimados en nuestro experimento de la media y varianza para Chi cuadrada son u_est= 2.904584087102939 var_est= 5.208870095007138

# %%
#Gamma con parametros k y theta t
k=2.54
t=0.43
from scipy.stats import gamma
mean, var, skew, kurt = gamma.stats(k, loc=0, scale=1/t, moments='mvsk',)
r = gamma.rvs (k, loc=0, scale=1/t, size=N)
plt.plot(r)
plt.title(str(N)+" puntos distribuidos Gamma con K="+str(k)+"y t="+str(t))
plt.show()
r.sort()
plt.plot(r)
plt.title(str(N)+" puntos distribuidos Gamma ordenados con k="+str(k)+"y t="+str(t))
plt.show()
plt.hist(r, bins = m)
plt.title("Histograma de los "+str(N)+" puntos distribuidos Gamma con k="+str(k)+"y t="+str(t))
plt.show()
print("EL tipo de nuestro arreglo r:")
print(type(r))
print("Vamos a hallar algunas estimaciones de estadisticas de r") 
avg=r.mean()
varest=r.var()
print("Los valores teoricos de la media y varianza para la Gamma son u=" ,mean,"var=",var)
print("Los valores estimados en nuestro experimento de la media y varianza para Gamma son u_est=" ,avg,"var_est=",varest)
# Out:
# EL tipo de nuestro arreglo r:
# <class 'numpy.ndarray'>
# Vamos a hallar algunas estimaciones de estadisticas de r
# Los valores teoricos de la media y varianza para la Gamma son u= 5.906976744186047 var= 13.73715521903732
# Los valores estimados en nuestro experimento de la media y varianza para Gamma son u_est= 5.733604693174432 var_est= 11.533161863309568
